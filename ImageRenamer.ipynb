# %%
import os
import shutil

renames = {
    'feature_correlation.png':            'Figure_1.png',
    'feature_importance_permutation.png': 'Figure_2a.png',
    'feature_importance_impurity.png':    'Figure_2b.png',
    'candidate_voting.png':               'Figure_3.png',
    'pairwise_consistency_grouped.png':   'Figure_4.png',
}

for old, new in renames.items():
    if os.path.exists(old):
        shutil.copy2(old, new)
        print(f'{old} → {new} (copy)')
    else:
        print(f'NOT FOUND: {old}')
# Out:
# feature_correlation.png → Figure_1.png (copy)
# feature_importance_permutation.png → Figure_2a.png (copy)
# feature_importance_impurity.png → Figure_2b.png (copy)
# candidate_voting.png → Figure_3.png (copy)
# pairwise_consistency_grouped.png → Figure_4.png (copy)
